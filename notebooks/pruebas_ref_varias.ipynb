# %%
# import mitsuba
import math

from scipy import constants as const

# import drjit
import drjit as dr
import matplotlib.pyplot as plt
import numpy as np

import mitsuba as mi

# colocar el valor de spectral
mi.set_variant("cuda_ad_spectral")

from mitsuba import ScalarTransform4f as T

# %%
def load_sensor_spectral(
    r: float,
    phi: float,
    theta: float,
    wave_lengths: np.ndarray,
    sigma: float,
    k: float = 3,
    n_wavelents: int = 5,
):
    """
    Load a sensor with Gaussian response.

    Args:
        r (float): Radius of the sensor.
        phi (float): Azimuthal angle in degrees.
        theta (float): Polar angle in degrees.
        wave_lengths (np.ndarray): Wavelengths for the Gaussian response.
        sigma (float): Standard deviation of the Gaussian.
        k (float, optional): Number of standard deviations. Default is 3.
        n_wavelents (int, optional): Number of wavelengths. Default is 5.
    """
    z = r * dr.sin(math.radians(theta))
    y = r * dr.cos(math.radians(theta)) * dr.sin(math.radians(phi))
    x = r * dr.cos(math.radians(theta)) * dr.cos(math.radians(phi))

    origin = np.array([x, y, z])

    film_dic = {
        "type": "specfilm",
        "width": 256,
        "height": 256,
        "rfilter": {
            "type": "gaussian",
        },
    }

    for i, wave_length in enumerate(wave_lengths):
        wmin = int(wave_length-1)
        wmax = int(wave_length)

        values = "1.0, 1.0"

        film_dic[f"band_{wave_length}"] = {
            "type": "regular",
            "wavelength_min": wmin,
            "wavelength_max": wmax,
            "values": values,
        }

    return {
        "type": "perspective",
        "fov": 40,
        "to_world": T().look_at(origin=origin, target=[0, 0, 0], up=[0, 0, 1]),
        "sampler": {"type": "multijitter", "sample_count": 16384, "seed": 42},
        "film": film_dic,
    }

# %%
def load_sensor_rgb(r, phi, theta):
    z = r * dr.sin(math.radians(theta))
    y = r * dr.cos(math.radians(theta)) * dr.sin(math.radians(phi))
    x = r * dr.cos(math.radians(theta)) * dr.cos(math.radians(phi))

    origin = np.array([x, y, z])

    return {
        "type": "perspective",
        "fov": 40,
        "to_world": T().look_at(origin=origin, target=[0, 0, 0], up=[0, 0, 1]),
        "sampler": {"type": "independent", "sample_count": 16},
        "film": {
            "type": "hdrfilm",
            "width": 256,
            "height": 256,
            "rfilter": {
                "type": "tent",
            },
            "pixel_format": "rgb",
        },
    }

# %%
def load_sensor_depth(r, phi, theta):
    z = r * np.sin(math.radians(theta))
    y = r * np.cos(math.radians(theta)) * np.sin(math.radians(phi))
    x = r * np.cos(math.radians(theta)) * np.cos(math.radians(phi))

    origin = np.array([x, y, z])

    return {
        "type": "perspective",
        "fov": 40,
        "to_world": T().look_at(origin=origin, target=[0, 0, 0], up=[0, 0, 1]),
        "sampler": {"type": "independent", "sample_count": 1},
        "film": {
            "type": "hdrfilm",
            "width": 256,
            "height": 256,
            "rfilter": {"type": "box"},
            "pixel_format": "luminance",
            "component_format": "float32",
        },
    }

# %%
wave_lengths = np.linspace(8000, 14000, 49).astype(int)

spp = 1024 * 16

sigma = 10
r = 35
phi = 0
theta = 0
k = 3
n = 15

sensor_espectral = mi.load_dict(
    load_sensor_spectral(r, phi, theta, wave_lengths, sigma, k, n)
)

# %%
def blackbody_radiance_nm(wavelengths_nm, temperature):
    """
    Compute spectral radiance B(λ, T) of a black body
    using scipy constants.

    Args:
        wavelengths_nm: array-like of wavelengths in nanometers (nm).
        temperature:    temperature in Kelvin (K).

    Returns:
        numpy array of spectral radiance in  μW/cm²/sr/μm (microflicks)
    """
    # Convert wavelengths to meters
    wavelengths_m = np.array(wavelengths_nm, dtype=float) * 1e-9

    # Planck's law for spectral radiance: from W/m²/sr/m
    exponent = (const.h * const.c) / (wavelengths_m * const.k * temperature)
    radiance = (2 * const.h * const.c**2) / (wavelengths_m**5) / (np.exp(exponent) - 1)

    # Convert radiance from W/m²/sr/m to μW/cm²/sr/μm
    radiance = radiance * 1e-4

    return radiance

# %%
dataBaseName = np.load("../assets/reference_data/matName_FullDatabase.npy", allow_pickle=True).item()[
    "matName"
]
dataBaseName = dataBaseName.squeeze()
dataBaseName = np.hstack(dataBaseName)  # lista de nombres de los materiales

dataBaseLib = np.load("../assets/reference_data/matLib_FullDatabase.npy", allow_pickle=True).item()[
    "matLib"
]
dataBaseLib = dataBaseLib[::-1, :]  # Reverso el orden de la base de datos

# vamos a asumir que las 49 firmas espectrales coinciden con las 49 longitudes de onda de la escena

print(dataBaseName.shape)
print(dataBaseLib.shape)
print(dataBaseName)
# Out:
# (30,)
# (49, 30)
# ['sky' 'asphalt' 'tilePavement' 'cinderblock' 'brick' 'wall' 'marble'
#  'stone' 'soil' 'al' 'weatheredMetal' 'brass' 'al2o3' 'oxidizedSteel'
#  'iron' 'carpaint' 'plasticPaint' 'yellowSpray' 'carwindow' 'crystalGlass'
#  'tire' 'cloths' 'card' 'tree' 'grass' 'flower' 'water' 'human' 'bark'
#  'concrete']

# %%
def detect_header_lines(file_path: str) -> int:
    skip_rows = 0
    
    with open(file_path, 'r') as file:
        for line_num, line in enumerate(file):
            line = line.strip()
            
            # Saltar líneas vacías
            if not line:
                skip_rows += 1
                continue
            
            # Intentar dividir la línea en columnas
            parts = line.split()
            
            # Verificar si la línea contiene al menos 2 números
            if len(parts) >= 2:
                try:
                    # Intentar convertir las primeras dos columnas a float
                    float(parts[0])
                    float(parts[1])
                    return skip_rows
                except ValueError:
                    # Esta línea no contiene números válidos, es parte del encabezado
                    skip_rows += 1
                    continue
            else:
                # Línea con menos de 2 columnas, es parte del encabezado
                skip_rows += 1
    
    raise ValueError("No se encontraron datos numéricos válidos en el archivo")

def extract_spectral_values(wavelengths: np.ndarray, file_path: str) -> np.ndarray:

    skips = detect_header_lines(file_path)

    data = np.loadtxt(file_path, skiprows=skips)

    waves = data[:, 0]*1000 # Convertir de micrómetros a nanómetros
    reflectance = data[:, 1]/100 # Convertir porcentaje a fracción
    emissivity = 1 - reflectance

    emissivity_values = []

    for wavelength in wavelengths:
        idx = np.argmin(np.abs(waves - wavelength))
        emissivity_values.append(emissivity[idx])

    emissivity_values = np.array(emissivity_values)

    return emissivity_values

# %%
# Ejemplo de uso con el archivo de firma espectral
firma_path = r"C:\Users\mgefr\Documents\1UIS\proyecto-grado\assets\materials\default.txt"

firma_test = extract_spectral_values(wave_lengths, firma_path)

plt.figure(figsize=(10, 6))
plt.plot(wave_lengths, firma_test)
plt.ylim(0,1)
plt.title("Firma de emisividad")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Emissividad")
plt.grid(True)
plt.show()

# %%
material = "stone"  # escoge el material que quieres
indice_material = np.where(dataBaseName == material)[0][
    0
]  # busca el indice del material en la base de datos

firma = dataBaseLib[:, indice_material]  # firma espectral del material

firma = extract_spectral_values(wave_lengths, firma_path)

# firma[24] = 0
# firma[25] = 0.5
# firma[26] = 1.0
# firma[27] = 0
# firma[28] = 0.5
# firma[29] = 1.0

print(firma.shape)

# plot
plt.figure(figsize=(10, 5))
plt.plot(wave_lengths, firma)
plt.title("Firma espectral del material")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Emisividad")
plt.ylim(0, 1)
plt.grid()
plt.show()
# Out:
# (49,)

# %%
def make_emissivity_3parts(
    wavelengths_um: np.ndarray,
    M_spikes: int = 6,              # número de picos aleatorios en la 3ra parte
    sigma_gauss_part1: float = 0.18,# sigma (en [0,1]) para la gaussiana del 1er tercio
    spike_amp_range=(0.4, 1.0),     # amplitud de picos aleatorios en 3er tercio
    spike_sigma_range_frac=(0.02, 0.10), # ancho relativo de picos (fracción del 3er tercio)
    seed: int | None = 42           # semilla para reproducibilidad
):
    """
    Genera ε(λ) en tres partes:
      1) Gaussiana (0→1→0) en el primer tercio.
      2) Rampa lineal 0→1 en el segundo tercio.
      3) Región con picos aleatorios 0..1 (suma de gaussianas) en el último tercio.

    Parameters
    ----------
    wavelengths_um : array (Nλ,)
    M_spikes : int
        Número de picos aleatorios en la 3ra parte.
    sigma_gauss_part1 : float
        Desviación típica (en coordenadas normalizadas [0,1]) de la gaussiana del 1er tercio.
    spike_amp_range : tuple(float, float)
        Rango de amplitudes para los picos aleatorios (0..1).
    spike_sigma_range_frac : tuple(float, float)
        Rango de sigmas como fracción del tamaño del 3er tercio (en unidades de índice).
    seed : int | None
        Semilla para RNG.

    Returns
    -------
    eps : np.ndarray (Nλ,) con valores en [0,1]
    parts_idx : dict con slices de cada parte {'p1': slice, 'p2': slice, 'p3': slice}
    """
    wl = np.asarray(wavelengths_um)
    N = wl.size
    assert N >= 9, "Se recomiendan al menos 9 bandas para dividir en 3 partes."

    # Particiones (enteros)
    n1 = N // 3
    n2 = 2 * N // 3
    s1 = slice(0, n1)
    s2 = slice(n1, n2)
    s3 = slice(n2, N)

    eps = np.zeros(N, dtype=float)

    # --- Parte 1: gaussiana normalizada en [0,1] ---
    x1 = np.linspace(0, 1, n1, endpoint=True)
    mu1 = 0.5
    sig1 = sigma_gauss_part1
    p1 = np.exp(-0.5 * ((x1 - mu1) / sig1) ** 2)  # ya queda 0..1 (pico=1)
    eps[s1] = p1

    # --- Parte 2: rampa 0 -> 1 ---
    if n2 - n1 > 0:
        eps[s2] = np.linspace(0, 1, n2 - n1, endpoint=True)

    # --- Parte 3: picos aleatorios 0..1 ---
    rng = np.random.default_rng(seed)
    n3 = N - n2
    x3 = np.arange(n3, dtype=float)

    # Base (opcional: ruido leve para “textura”)
    p3 = np.zeros(n3, dtype=float)

    # Generar picos gaussianos
    # sigma en índices del 3er tercio (no en µm); control con fracción
    sig_min = max(1.0, spike_sigma_range_frac[0] * n3)
    sig_max = max(sig_min, spike_sigma_range_frac[1] * n3)

    for _ in range(M_spikes):
        c = rng.uniform(0, n3 - 1)  # centro (en índice fraccional)
        a = rng.uniform(*spike_amp_range)
        s = rng.uniform(sig_min, sig_max)
        p3 += a * np.exp(-0.5 * ((x3 - c) / s) ** 2)

    # Normalizar p3 a [0,1] si supera 1
    if p3.max() > 0:
        p3 = p3 / p3.max()

    eps[s3] = p3

    # Clip final a [0,1]
    eps = np.clip(eps, 0.0, 1.0)

    parts_idx = {"p1": s1, "p2": s2, "p3": s3}
    return eps, parts_idx

# %%
# Rejilla espectral (ajústala a tus bandas reales)
wl = np.linspace(8.0, 14.0, 49)

eps, parts = make_emissivity_3parts(
    wl,
    M_spikes=8,                 # más picos si quieres región bien “rica”
    sigma_gauss_part1=0.20,     # gaussiana algo más ancha en la 1a parte
    spike_amp_range=(0.3, 1.0), # amplitudes 0.3..1.0
    spike_sigma_range_frac=(0.03, 0.12), # picos de ancho corto a medio
    seed=1234
)

# (Opcional) Visualización rápida
# import matplotlib.pyplot as plt
# plt.plot(wl, eps, marker='o'); plt.xlabel('λ (µm)'); plt.ylabel('ε'); plt.ylim(0,1); plt.show()
plt.figure(figsize=(10, 5))
plt.plot(wl, eps)
plt.title("Emisividad sintética en 3 partes")
plt.xlabel("Longitud de onda (µm)")
plt.ylabel("Emisividad")
plt.ylim(0, 1)
plt.grid()
plt.show()

# %%
temperatura = 310.15  # temperatura objeto
temperatura_aire = 353.15

wave_lengths = np.linspace(8000, 14000, 49).astype(int)

black_body = blackbody_radiance_nm(wave_lengths, temperatura)  # radiancia del objeto
black_body_air = blackbody_radiance_nm(wave_lengths, temperatura_aire)  # radiancia del aire

firma = eps

emision = black_body * firma  # emision del objeto

reflectance = (1-firma)

# subplots
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(wave_lengths/1000, firma, label='Emisividad', color='orange')
plt.plot(wave_lengths/1000, reflectance, label='Reflectancia', color='blue', linestyle='--')
plt.title(f"Firma espectral del material")
plt.xlabel("Longitud de onda (μm)")
plt.ylabel("Emisividad")
plt.ylim(-0.1, 1.1)
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(wave_lengths/1000, emision, label='Emisión')
plt.plot(wave_lengths/1000, black_body, linestyle='--', label='Cuerpo Negro')
plt.title(f"Emision del objeto T = {temperatura} K")
plt.xlabel("Longitud de onda (μm)")
plt.ylabel("Radiancia (μW/cm²/sr/μm)")
plt.grid()
plt.legend()

plt.show()

# %%
def lista_a_string(valores):
    return ", ".join(str(v) for v in valores)

# %%
dragon_emision = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}

dragon_blackbody = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(black_body),
        },
    },
}

dragon_air = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(black_body_air),
        },
    },
}

dragon_emision_reflectance = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "bsdf": {
        "type": "diffuse",
        "reflectance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values":      lista_a_string(reflectance),
        },
    },
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}

# %%
def get_attenuation_for_wavelengths(wavelengths: np.ndarray, attenuation_file: str = "air") -> np.ndarray:

        wavelengths_um = wavelengths / 1000.0

        try:
            # Construir la ruta del archivo
            file_path = f"../assets/reference_data/{attenuation_file}.txt"
            
            # Cargar los datos del archivo
            trans_array = np.loadtxt(file_path)
            
            # Extraer columnas: [wavelength, transmittance, attenuation]
            file_wavelengths = trans_array[:, 0]  # Primera columna: longitudes de onda
            file_attenuation = trans_array[:, 2]  # Tercera columna: atenuación
            
            # Encontrar los índices más cercanos para cada longitud de onda deseada
            attenuation_values = []
            
            for target_wavelength in wavelengths_um:
                # Encontrar el índice del valor más cercano
                closest_index = np.argmin(np.abs(file_wavelengths - target_wavelength))
                attenuation_values.append(file_attenuation[closest_index])

            original = np.array(attenuation_values)
            
            attenuation_array = np.array(attenuation_values)

            attenuation_array = attenuation_array * (np.log(10) / 10)
            
            return [attenuation_array, original]

        except (OSError, ValueError) as e:
            raise RuntimeError("Error al obtener la atenuación") from e

# %%
attenation_file = "air"
sigma_t, original_sigma_t = get_attenuation_for_wavelengths(wave_lengths, attenation_file)



# sigma_t[24] = 0
# sigma_t[25] = 0
# sigma_t[26] = 0
# sigma_t[27] = 1
# sigma_t[28] = 1
# sigma_t[29] = 1

plt.figure(figsize=(15, 4))
plt.subplot(1, 3, 1)
plt.plot(wave_lengths, sigma_t, label="Atenuacion (neper)")
plt.title("Atenuacion (neper)")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Atenuacion")
plt.grid()
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(wave_lengths, original_sigma_t, label="Atenuacion (dB/m)")
plt.title("Atenuacion (dB/m)")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Atenuacion")
plt.grid()
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(wave_lengths, sigma_t, label="Atenuacion (neper)")
plt.plot(wave_lengths, original_sigma_t, label="Atenuacion (dB/m)")
plt.title("Atenuacion comparación")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Atenuacion")
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()

# %%
atenuacion, parts = make_emissivity_3parts(
    wl,
    M_spikes=8,                 # más picos si quieres región bien “rica”
    sigma_gauss_part1=0.20,     # gaussiana algo más ancha en la 1a parte
    spike_amp_range=(0.3, 1.0), # amplitudes 0.3..1.0
    spike_sigma_range_frac=(0.03, 0.12), # picos de ancho corto a medio
    seed=999999
)

atenuacion = atenuacion * 0.1

plt.figure(figsize=(10, 5))
plt.plot(wl, atenuacion)
plt.title("Atenuacion sintética en 3 partes")
plt.xlabel("Longitud de onda (µm)")
plt.ylabel("Atenuacion (neper)")
plt.grid()
plt.show()

sigma_t = atenuacion

# %%
niebla = {
    "type": "homogeneous",  # medio homogeneo, es decir el mismo sigma en todo el espacio,
    "id": "niebla",  # identificador del medio, para referenciarlo
    "albedo": {
        "type": "constvolume",  # textura volumétrica constante
        "value": {"type": "uniform", "value": 0.0},
    },
    "sigma_t": {
        "type": "constvolume",
        "value": {
            "type": "irregular",  # definimos un espectro
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(sigma_t),
        },
    },
    "phase": {  # define como se dispersa la luz en el medio (no la he entendido bien)
        "type": "hg",
        "g": 0.95,  # usar valores de 0.9-0.95 que es lo que pasa en el infrarrojo lejano, preguntarle al profe
        # con este nuevo valor pareciera que no existiera niebla, pero si lo pongo en 0.0 se ve la niebla
    },
}

# %%
plt.figure(figsize=(10, 5))
plt.plot(wave_lengths/1000, sigma_t)
plt.title("Atenuacion")
plt.xlabel('Longitud de onda (μm)')
plt.ylabel("Atenuacion (neper)")
plt.grid()
plt.show()

# %%
sensor_espectral_niebla = load_sensor_spectral(r, phi, theta, wave_lengths, sigma, k, n)
sensor_espectral_niebla["medium"] = {"type": "ref", "id": "niebla"}

sensor_espectral_sin_niebla = load_sensor_spectral(
    r, phi, theta, wave_lengths, sigma, k, n
)

sensor_depth = load_sensor_depth(r, phi, theta)

# %%
integrador_niebla = {"type": "volpathmis", "max_depth": 8}

integrador_sin_niebla = {"type": "path"}

# %%
scene_sin_niebla = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador_sin_niebla,
        "sensor": sensor_espectral_sin_niebla,
        "dragon": dragon_emision,
    }
)

scene_niebla = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador_niebla,
        "niebla": niebla,
        "sensor": sensor_espectral_niebla,
        "dragon": dragon_emision,
    }
)
scene_depth = mi.load_dict(
    {
        "type": "scene",
        "integrator": {
            "type": "depth",
        },
        "sensor": sensor_depth,
        "dragon": dragon_emision,
    }
)

# scene_sin_niebla_reflectance = mi.load_dict(
#     {
#         "type": "scene",
#         "integrator": integrador_sin_niebla,
#         "sensor": sensor_espectral_sin_niebla,
#         "dragon": dragon_emision_reflectance,
#         "emitter": {
#             "type": "constant",
#             "radiance": {
#                 "type": "irregular",
#                 "wavelengths": lista_a_string(wave_lengths),
#                 "values": lista_a_string(black_body_air),
#             },
#         },
#     }
# )

# scene_niebla_reflectance = mi.load_dict(
#     {
#         "type": "scene",
#         "integrator": integrador_niebla,
#         "niebla": niebla,
#         "sensor": sensor_espectral_niebla,
#         "dragon": dragon_emision_reflectance,
#         "emitter": {
#             "type": "constant",
#             "radiance": {
#                 "type": "irregular",
#                 "wavelengths": lista_a_string(wave_lengths),
#                 "values": lista_a_string(black_body_air),
#             },
#         },
#     }
# )

# %%
#imagen_niebla = mi.render(scene_niebla, spp=spp)
#imagen_sin_niebla = mi.render(scene_sin_niebla, spp=spp)
#imagen_depth = mi.render(scene_depth, spp=spp)
#imagen_niebla_reflectance = mi.render(scene_niebla_reflectance, spp=spp)
#imagen_sin_niebla_reflectance = mi.render(scene_sin_niebla_reflectance, spp=spp)

# %%
def RMSE (array1, array2):
    return np.sqrt(np.mean((array1 - array2) ** 2))

def NRMSE (array1, array2):
    return RMSE(array1, array2) / (np.max(array2) - np.min(array2))

# %%
wave_lengths = np.linspace(8000, 14000, 49).astype(int)

spp = 1024 * 16 
x = 200
y = 250

# %%
temperatura = 310.15  # temperatura objeto
temperatura_aire = 303.15

wave_lengths = np.linspace(8000, 14000, 49).astype(int)

black_body = blackbody_radiance_nm(wave_lengths, temperatura)  # radiancia del objeto
black_body_air = blackbody_radiance_nm(wave_lengths, temperatura_aire)  # radiancia del aire

emision = black_body * firma  # emision del objeto

dragon = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "bsdf": {
        "type": "diffuse",
        "reflectance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values":      lista_a_string(reflectance),
        },
    },
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}
    
dragon_sin_reflectancia = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}

niebla = {
    "type": "homogeneous", 
    "id": "niebla", 
    "albedo": {
        "type": "constvolume", 
        "value": {"type": "uniform", "value": 0.0},
    },
    "sigma_t": {
        "type": "constvolume",
        "value": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(sigma_t),
        },
    },
    "phase": {
        "type": "hg",
        "g": 0.95, 
    },
}

sensor = load_sensor_spectral(
    r, phi, theta, wave_lengths, sigma, k, n
)

sensor["medium"] = {"type": "ref", "id": "niebla"}

sensor_depth = load_sensor_depth(r, phi, theta)

integrador = {"type": "volpathmis", "max_depth": 16}

integrador_depth = {"type": "depth"}

scene = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        "niebla": niebla,
        "sensor": sensor,
        "dragon": dragon,
        "emitter": {
            "type": "constant",
            "radiance": {
                "type": "irregular",
                "wavelengths": lista_a_string(wave_lengths),
                "values": lista_a_string(black_body_air),
            },
        },
    }
)

scena_sin_reflectancia = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        "niebla": niebla,
        "sensor": sensor,
        "dragon": dragon_sin_reflectancia,
        "emitter": {
            "type": "constant",
            "radiance": {
                "type": "irregular",
                "wavelengths": lista_a_string(wave_lengths),
                "values": lista_a_string(black_body_air),
            },
        },
    }
)

scena_reflectancia_sin_niebla = mi.load_dict(
    {
        "type": "scene",
        "integrator": {"type": "path"},
        "sensor": load_sensor_spectral(r, phi, theta, wave_lengths, sigma, k, n),
        "dragon": dragon,
        "emitter": {
            "type": "constant",
            "radiance": {
                "type": "irregular",
                "wavelengths": lista_a_string(wave_lengths),
                "values": lista_a_string(black_body_air),
            },
        },
    }
)

scene_depth = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador_depth,
        "sensor": sensor_depth,
        "dragon": dragon,
    }
)

# %%
depth = mi.render(scene_depth, spp=spp)

# %%
T_teorico = np.exp(-sigma_t * depth[y, x])

# %%
plt.figure(figsize=(10, 5))
plt.imshow(depth, cmap='magma')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.colorbar(label='Depth (m)')
plt.title("Mapa de profundidad")
plt.show()

# %%
image = mi.render(scene, spp=spp//8)

# %%
banda = 39
plt.figure(figsize=(10, 5))
plt.imshow(image[:, :, banda], cmap='magma')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.colorbar(label='Radiancia (μW/cm²/sr/μm)')
plt.title(f"Imagen renderizada - Banda {wave_lengths[banda]} nm")
plt.show()

# %%
imagen_sin_reflectancia = mi.render(scena_sin_reflectancia, spp=spp//8)

# %%
imagen_reflectancia_sin_niebla = mi.render(scena_reflectancia_sin_niebla, spp=spp//8)

# %%
T_teorico = np.exp(-sigma_t * depth[y,x])  # Transmitancia teorica
L_obj = T_teorico * firma * black_body  # Radiancia del objeto teorica
L_ref = T_teorico * (1-firma) * black_body_air  # Radiancia reflejada teorica
L_total = L_obj  + L_ref # Radiancia total teorica
L_air = (1-T_teorico) * black_body_air  # Radiancia del aire teorica
L_test = L_total + L_air

print(T_teorico.shape)
print(L_obj.shape)
print(L_ref.shape)
print(L_total.shape)
print(L_air.shape)
# Out:
# (49,)
# (49,)
# (49,)
# (49,)
# (49,)

# %%
plt.plot(wave_lengths/1000, sigma_t, label="atenuación")
plt.title("Atenuación")
plt.xlabel('Longitud de onda (μm)')
plt.ylabel("Atenuación (neper)")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15, 15))

plt.subplot(2, 1, 1)
plt.plot(wave_lengths/1000, T_teorico, label='Transmitancia teorica')
plt.plot(wave_lengths/1000, firma, label='Emisividad')
plt.plot(wave_lengths/1000, reflectance, label='Reflectancia')
plt.title("Transmitancia, Emisividad y Reflectancia")
plt.xlabel("Longitud de onda (μm)")
plt.ylabel("Valor")
plt.ylim(-0.1, 1.1)
plt.grid()
plt.legend()


plt.subplot(2, 1, 2)
#plt.plot(wave_lengths/1000, image[y, x, :], label='Radiancia simulada')
#plt.plot(wave_lengths/1000, L_total, linestyle='--', label='Radiancia teorica')
plt.plot(wave_lengths/1000, black_body, linestyle=':', label='Radiancia de cuerpo negro')
plt.plot(wave_lengths/1000, L_air, linestyle='-.', label='Radiancia del aire')
#plt.plot(wave_lengths/1000, L_test, linestyle='-', label='Radiancia total con lair test')
plt.plot(wave_lengths/1000, image[y, x, :] + L_air, linestyle='-', label='Simulada + L_air')
plt.plot(wave_lengths/1000, black_body_air, linestyle='-', label='B_air')
plt.plot(wave_lengths/1000, imagen_sin_reflectancia[y,x,:], linestyle='-', label='Simulada sin reflectancia')
plt.plot(wave_lengths/1000, imagen_reflectancia_sin_niebla[y,x,:], linestyle='-', label='Simulada sin niebla')
plt.title("Radiancia en el pixel")
plt.xlabel("Longitud de onda (μm)")
plt.ylabel("Radiancia (μW/cm²/sr/μm)")
plt.grid()
plt.legend()
plt.show()

# %%
temperatura = 310.15  # temperatura objeto
temperatura_aire = 303.15

wave_lengths = np.linspace(8000, 14000, 49).astype(int)

black_body = blackbody_radiance_nm(wave_lengths, temperatura)  # radiancia del objeto
black_body_air = blackbody_radiance_nm(wave_lengths, temperatura_aire)  # radiancia del aire

emision = black_body * firma  # emision del objeto
reflectancia_aire = (1-firma) * black_body_air
emision = emision + reflectancia_aire # emision del objeto

dragon = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "bsdf": {
        "type": "diffuse",
        "reflectance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values":      lista_a_string(reflectance),
        },
    },
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}

niebla = {
    "type": "homogeneous", 
    "id": "niebla", 
    "albedo": {
        "type": "constvolume", 
        "value": {"type": "uniform", "value": 0.0},
    },
    "sigma_t": {
        "type": "constvolume",
        "value": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(sigma_t),
        },
    },
    "phase": {
        "type": "hg",
        "g": 0.95, 
    },
}

sensor = load_sensor_spectral(
    r, phi, theta, wave_lengths, sigma, k, n
)

sensor["medium"] = {"type": "ref", "id": "niebla"}

integrador = {"type": "volpathmis", "max_depth": 16}


scene = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        "niebla": niebla,
        "sensor": sensor,
        "dragon": dragon,
        # quitamos la emision de luz ambiental
        # "emitter": {
        #     "type": "constant",
        #     "radiance": {
        #         "type": "irregular",
        #         "wavelengths": lista_a_string(wave_lengths),
        #         "values": lista_a_string(black_body_air),
        #     },
        # },
    }
)

# %%
test_medicion_ref_air = mi.render(scene, spp=spp//8)

# %%
banda = 30

print(wave_lengths[banda])

plt.imshow(test_medicion_ref_air[:,:,banda], cmap='magma')
plt.colorbar(label='Radiancia (μW/cm²/sr/μm)')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.title("Radiancia total en el sensor")
plt.show()
# Out:
# 11750

# %%
L_obs_directa = test_medicion_ref_air[y,x,:]
L_obs_completa = test_medicion_ref_air[y,x,:] + L_air

# %%
# inspeccion visual
plt.figure(figsize=(10, 5))
plt.plot(wave_lengths/1000, L_obs_directa, label='Radiancia observada directa')
plt.plot(wave_lengths/1000, L_obs_completa, label='Radiancia observada completa')
plt.plot(wave_lengths/1000, L_test, linestyle='--', label='Radiancia teorica')
plt.plot(wave_lengths/1000, black_body, linestyle=':', label='Radiancia de cuerpo negro')
plt.plot(wave_lengths/1000, black_body_air, linestyle='-', label='Radiancia de cuerpo negro en aire')
plt.xlabel('Longitud de onda (µm)')
plt.ylabel('Radiancia (W/m²/µm/sr)')
plt.legend()

# %%
L_obj = T_teorico * firma * black_body  # Radiancia del objeto teorica
L_ref = T_teorico * (1-firma) * black_body_air  # Radiancia reflejada teorica
L_air = (1-T_teorico) * black_body_air  # Radiancia del aire teorica
L_obs = L_obj + L_ref + L_air

# %%
plt.figure(figsize=(10, 5))
plt.plot(wave_lengths/1000, black_body, linestyle='--', label='Radiancia observada directa')
plt.plot(wave_lengths/1000, black_body_air, linestyle='--', label='Radiancia de cuerpo negro en aire')
plt.plot(wave_lengths/1000, L_obj, label='Radiancia del objeto teorica')
plt.plot(wave_lengths/1000, L_ref, label='Radiancia reflejada teorica')
plt.plot(wave_lengths/1000, L_air, label='Radiancia del aire teorica')
plt.plot(wave_lengths/1000, L_obs, linestyle='-', label='Radiancia observada')

plt.grid()
plt.legend()
plt.xlabel('Longitud de onda (μm)')
plt.ylabel('Radiancia (μW/cm²/sr/μm)')
plt.ylim(0, None)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(wave_lengths/1000, black_body, linestyle='--', label='Radiancia observada directa')
plt.plot(wave_lengths/1000, black_body_air, linestyle='--', label='Radiancia de cuerpo negro en aire')
plt.plot(wave_lengths/1000, L_obj, label='Radiancia del objeto teorica')
plt.plot(wave_lengths/1000, L_ref, label='Radiancia reflejada teorica')
plt.plot(wave_lengths/1000, L_air, label='Radiancia del aire teorica')
plt.plot(wave_lengths/1000, emision, linestyle='-', label='emision')
plt.plot(wave_lengths/1000, emision*T_teorico, linestyle='-', label='emision * T_teorico')

plt.grid()
plt.legend()
plt.xlabel('Longitud de onda (μm)')
plt.ylabel('Radiancia (μW/cm²/sr/μm)')
plt.ylim(0, None)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(wave_lengths/1000, black_body, linestyle='--', label='Radiancia observada directa')
plt.plot(wave_lengths/1000, black_body_air, linestyle='--', label='Radiancia de cuerpo negro en aire')
plt.plot(wave_lengths/1000, L_obj+L_ref, label='Radiancia del objeto y reflejada teorica')
plt.plot(wave_lengths/1000, emision, linestyle='-', label='emision')
plt.plot(wave_lengths/1000, emision*T_teorico, linestyle='-', label='emision * T_teorico')
plt.plot(wave_lengths/1000, L_air, linestyle='-', label='L_air')
plt.plot(wave_lengths/1000, emision*T_teorico+L_air, linestyle='-', label='L_obs')

plt.grid()
plt.legend()
plt.xlabel('Longitud de onda (μm)')
plt.ylabel('Radiancia (μW/cm²/sr/μm)')
plt.ylim(0, None)
plt.show()

# %%
temperatura = 310.15  # temperatura objeto
temperatura_aire = 303.15

wave_lengths = np.linspace(8000, 14000, 49).astype(int)

black_body = blackbody_radiance_nm(wave_lengths, temperatura)  # radiancia del objeto
black_body_air = blackbody_radiance_nm(wave_lengths, temperatura_aire)  # radiancia del aire

emision = black_body * firma  # emision del objeto
reflectancia_aire = (1-firma) * black_body_air
emision = emision + reflectancia_aire # emision del objeto

dragon = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "bsdf": {
        "type": "diffuse",
        "reflectance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values":      lista_a_string(reflectance),
        },
    },
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}

niebla = {
    "type": "homogeneous", 
    "id": "niebla", 
    "albedo": {
        "type": "constvolume", 
        "value": {"type": "uniform", "value": 0.0},
    },
    "sigma_t": {
        "type": "constvolume",
        "value": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(sigma_t),
        },
    },
    "phase": {
        "type": "hg",
        "g": 0.95, 
    },
}

sensor = load_sensor_spectral(
    r, phi, theta, wave_lengths, sigma, k, n
)

#sensor["medium"] = {"type": "ref", "id": "niebla"}

integrador = {"type": "path"}


scene = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        #"niebla": niebla,
        "sensor": sensor,
        "dragon": dragon,
        # quitamos la emision de luz ambiental
        # "emitter": {
        #     "type": "constant",
        #     "radiance": {
        #         "type": "irregular",
        #         "wavelengths": lista_a_string(wave_lengths),
        #         "values": lista_a_string(black_body_air),
        #     },
        # },
    }
)

# %%
imagen_test_sin_niebla = mi.render(scene, spp=spp//8)

# %%
plt.figure(figsize=(10, 5))
plt.plot(wave_lengths/1000, imagen_test_sin_niebla[y, x, :], label='Radiancia simulada sin niebla')
plt.plot(wave_lengths/1000, test_medicion_ref_air[y, x, :], label='Radiancia simulada con niebla')

plt.grid()
plt.legend()
plt.show()

# %%
temperatura = 310.15  # temperatura objeto
temperatura_aire = 303.15

wave_lengths = np.linspace(8000, 14000, 49).astype(int)

black_body = blackbody_radiance_nm(wave_lengths, temperatura)  # radiancia del objeto
black_body_air = blackbody_radiance_nm(wave_lengths, temperatura_aire)  # radiancia del aire

emision = black_body * firma  # emision del objeto
reflectancia_aire = (1-firma) * black_body_air
emision = emision + reflectancia_aire # emision del objeto

dragon = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "bsdf": {
        "type": "diffuse",
        "reflectance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values":      lista_a_string(reflectance),
        },
    },
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}

niebla = {
    "type": "homogeneous", 
    "id": "niebla", 
    "albedo": {
        "type": "constvolume", 
        "value": {"type": "uniform", "value": 0.0},
    },
    "sigma_t": {
        "type": "constvolume",
        "value": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(sigma_t),
        },
    },
    "phase": {
        "type": "hg",
        "g": 0.95, 
    },
}

sensor = load_sensor_spectral(
    r, phi, theta, wave_lengths, sigma, k, n
)

sensor["medium"] = {"type": "ref", "id": "niebla"}

integrador = {"type": "volpathmis", "max_depth": 1}


scene = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        "niebla": niebla,
        "sensor": sensor,
        "dragon": dragon,
        # quitamos la emision de luz ambiental
        # "emitter": {
        #     "type": "constant",
        #     "radiance": {
        #         "type": "irregular",
        #         "wavelengths": lista_a_string(wave_lengths),
        #         "values": lista_a_string(black_body_air),
        #     },
        # },
    }
)

# %%
imagen_test_no_bsdf_no_niebla = mi.render(scene, spp=spp//8)

# %%
plt.imshow(imagen_test_no_bsdf_no_niebla[:,:,0], cmap='magma')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.colorbar(label='Radiancia (μW/cm²/sr/μm)')

# %%
plt.figure(figsize=(10, 5))
plt.plot(wave_lengths/1000, imagen_test_no_bsdf_no_niebla[y, x, :], label='Radiancia simulada')
plt.plot(wave_lengths/1000, black_body_air, label='B_air')
plt.plot(wave_lengths/1000, black_body, label='B_obj')
plt.plot(wave_lengths/1000, emision, label='E_obj')
plt.plot(wave_lengths/1000, imagen_test_no_bsdf_no_niebla[y, x, :] + L_air, label='L_obs')

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # La prueba definitiva

# %%
temperatura = 310.15  # temperatura objeto
temperatura_aire = 303.15

wave_lengths = np.linspace(8000, 14000, 49).astype(int)

black_body = blackbody_radiance_nm(wave_lengths, temperatura)  # radiancia del objeto
black_body_air = blackbody_radiance_nm(wave_lengths, temperatura_aire)  # radiancia del aire

emision = black_body * firma 
emision_ref_air = (1-firma) * black_body_air

sigma_t = sigma_t * 1e-5

dragon = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "bsdf": {
        "type": "diffuse",
        "reflectance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values":      lista_a_string(reflectance),
        },
    },
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}

dragon_ref_air = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision_ref_air),
        },
    },
}

niebla = {
    "type": "homogeneous", 
    "id": "niebla", 
    "albedo": {
        "type": "constvolume", 
        "value": {"type": "uniform", "value": 0.0},
    },
    "sigma_t": {
        "type": "constvolume",
        "value": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(sigma_t),
        },
    },
    "phase": {
        "type": "hg",
        "g": 0.95, 
    },
}

sensor = load_sensor_spectral(
    r, phi, theta, wave_lengths, sigma, k, n
)

sensor["medium"] = {"type": "ref", "id": "niebla"}

integrador = {"type": "volpathmis", "max_depth": 16}


scene = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        "niebla": niebla,
        "sensor": sensor,
        "dragon": dragon,
        # quitamos la emision de luz ambiental
        # "emitter": {
        #     "type": "constant",
        #     "radiance": {
        #         "type": "irregular",
        #         "wavelengths": lista_a_string(wave_lengths),
        #         "values": lista_a_string(black_body_air),
        #     },
        # },
    }
)

scene_ref_air = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        "niebla": niebla,
        "sensor": sensor,
        "dragon": dragon_ref_air,
    }
)

# %%
imagen = mi.render(scene, spp=spp//8)
ref_air = mi.render(scene_ref_air, spp=spp//8)

# %%
banda = 0
print(firma[banda])
plt.imshow(imagen[:,:,banda], cmap='magma')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.colorbar(label='Radiancia (μW/cm²/sr/μm)')
plt.title(f'wavelength {wave_lengths[banda]} nm')
# Out:
# 0.04393693362340742
# Text(0.5, 1.0, 'wavelength 8000 nm')

# %%
print(1-firma[banda])
plt.imshow(ref_air[:,:,banda], cmap='magma')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.colorbar(label='Radiancia (μW/cm²/sr/μm)')
plt.title(f'wavelength {wave_lengths[banda]} nm')
plt.title('Radiancia reflejada del aire')
# Out:
# 0.9560630663765926
# Text(0.5, 1.0, 'Radiancia reflejada del aire')

# %%
resultado = imagen + ref_air

transmitancia = np.exp(-sigma_t * depth[y,x])

L_obj = transmitancia * firma * black_body  # Radiancia del objeto teorica
transmitancia = np.exp(-sigma_t * depth[y,x])
L_air = (1-transmitancia) * black_body_air  # Radiancia del aire teorica
resultado_antiguo = imagen[y,x,:] + (1-transmitancia) * black_body_air
resultado_nuevo = imagen[y,x,:] + (1-transmitancia) * black_body_air + ref_air[y,x,:]
resultado_teorico = L_obj + L_air + ref_air[y,x,:]

plt.figure(figsize=(15, 6))
plt.plot(wave_lengths/1000, resultado_antiguo, label='Metodo antiguo')
plt.plot(wave_lengths/1000, ref_air[y, x, :], label='Radiancia reflejada del aire')
plt.plot(wave_lengths/1000, resultado_nuevo, label='Metodo nuevo')
#plt.plot(wave_lengths/1000, resultado_teorico, linestyle='--', label='Radiancia teorica')
plt.plot(wave_lengths/1000, black_body_air, label='B_air')
plt.plot(wave_lengths/1000, black_body, label='B_obj')
plt.plot(wave_lengths/1000, L_obj, label='L_obj')
plt.plot(wave_lengths/1000, L_air, label='L_air')

plt.grid()
# Leyenda debajo de la gráfica
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=4, frameon=True)
plt.subplots_adjust(bottom=0.1)
plt.show()

# %%
teorico_air_ref = (1-firma) * black_body_air * transmitancia

plt.figure(figsize=(15, 6))
plt.plot(wave_lengths/1000, ref_air[y, x, :], label='Radiancia reflejada del aire')
plt.plot(wave_lengths/1000, teorico_air_ref, linestyle='--', label='Radiancia reflejada del aire teorica')


plt.grid()
# Leyenda debajo de la gráfica
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=4, frameon=True)
plt.subplots_adjust(bottom=0.1)
plt.show()

# %% [markdown]
# # segunda prueba

# %%
temperatura = 310.15  # temperatura objeto
temperatura_aire = 303.15

wave_lengths = np.linspace(8000, 14000, 49).astype(int)

black_body = blackbody_radiance_nm(wave_lengths, temperatura)  # radiancia del objeto
black_body_air = blackbody_radiance_nm(wave_lengths, temperatura_aire)  # radiancia del aire

emision = black_body * firma 
emision_ref_air = (1-firma) * black_body_air

dragon = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "bsdf": {
        "type": "diffuse",
        "reflectance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values":      lista_a_string(reflectance),
        },
    },
    "emitter": {
        "type": "area",
        "radiance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(emision),
        },
    },
}

dragon_ref_air = {
    "type": "obj",
    "filename": "Dragon.obj",
    "to_world": T().translate([0, 0, 0]),
    "bsdf": {
        "type": "diffuse",
        "reflectance": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values":      lista_a_string(reflectance),
        },
    },
}

niebla = {
    "type": "homogeneous", 
    "id": "niebla", 
    "albedo": {
        "type": "constvolume", 
        "value": {"type": "uniform", "value": 0.0},
    },
    "sigma_t": {
        "type": "constvolume",
        "value": {
            "type": "irregular",
            "wavelengths": lista_a_string(wave_lengths),
            "values": lista_a_string(sigma_t),
        },
    },
    "phase": {
        "type": "hg",
        "g": 0.95, 
    },
}

sensor = load_sensor_spectral(
    r, phi, theta, wave_lengths, sigma, k, n
)

sensor["medium"] = {"type": "ref", "id": "niebla"}

integrador = {"type": "volpathmis", "max_depth": 16}


scene = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        "niebla": niebla,
        "sensor": sensor,
        "dragon": dragon,
        # quitamos la emision de luz ambiental
        # "emitter": {
        #     "type": "constant",
        #     "radiance": {
        #         "type": "irregular",
        #         "wavelengths": lista_a_string(wave_lengths),
        #         "values": lista_a_string(black_body_air),
        #     },
        # },
    }
)

sensor_no_medium = load_sensor_spectral(
    r, phi, theta, wave_lengths, sigma, k, n
)

scene_ref_air = mi.load_dict(
    {
        "type": "scene",
        "integrator": integrador,
        #"niebla": niebla,
        "sensor": sensor_no_medium,
        "dragon": dragon_ref_air,
        "emitter": {
            "type": "constant",
            "radiance": {
                "type": "irregular",
                "wavelengths": lista_a_string(wave_lengths),
                "values": lista_a_string(black_body_air),
            },
        },
    }
)

# %%
imagen_2 = mi.render(scene, spp=spp//8)
ref_air_2 = mi.render(scene_ref_air, spp=spp//8)

# %%
banda = 0
print(firma[banda])
plt.imshow(imagen_2[:,:,banda], cmap='magma')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.colorbar(label='Radiancia (μW/cm²/sr/μm)')
plt.title(f'wavelength {wave_lengths[banda]} nm')
# Out:
# 0.04393693362340742
# Text(0.5, 1.0, 'wavelength 8000 nm')

# %%
print(1-firma[banda])
plt.imshow(ref_air_2[:,:,banda], cmap='magma')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.colorbar(label='Radiancia (μW/cm²/sr/μm)')
plt.title(f'wavelength {wave_lengths[banda]} nm')
# Out:
# 0.9560630663765926
# Text(0.5, 1.0, 'wavelength 8000 nm')

# %%
shape = imagen_2.shape
new_sigma_t = np.zeros((shape[0], shape[1], shape[2]))
for i in range(shape[2]):
    new_sigma_t[:, :, i] = sigma_t[i]

print(new_sigma_t.shape)
expo = new_sigma_t *  depth
print(expo.shape)
transmitancia_map = np.exp(-expo)
print(transmitancia_map.shape)
# Out:
# (256, 256, 49)
# (256, 256, 49)
# (256, 256, 49)

# %%
mask = np.where(depth == 0, 0, 1)

plt.imshow(mask, cmap='gray')

# %%
print(transmitancia[banda])
ref_air_3 = ref_air_2 * transmitancia_map
print(ref_air_3.shape)
ref_air_3 = ref_air_3 * mask
print(ref_air_3.shape)
plt.imshow(ref_air_3[:,:,banda], cmap='magma')
plt.plot(x, y, 'bo')  # marcar el píxel (x, y) en azul
plt.colorbar(label='Radiancia (μW/cm²/sr/μm)')
plt.title(f'wavelength {wave_lengths[banda]} nm')
# Out:
# 0.9999986280303655
# (256, 256, 49)
# (256, 256, 49)
# Text(0.5, 1.0, 'wavelength 8000 nm')

# %%
transmitancia = np.exp(-sigma_t * depth[y,x])

L_obj = T_teorico * firma * black_body  # Radiancia del objeto teorica
L_air = (1-transmitancia) * black_body_air  # Radiancia del aire teorica
resultado_antiguo = imagen_2[y,x,:] + (1-transmitancia) * black_body_air
resultado_nuevo_2 = imagen_2[y,x,:] + (1-transmitancia) * black_body_air + ref_air_2[y,x,:]*transmitancia
resultado_teorico = L_obj + L_air + ref_air_2[y,x,:]

plt.figure(figsize=(15, 6))
plt.plot(wave_lengths/1000, resultado_antiguo, label='Metodo antiguo')
plt.plot(wave_lengths/1000, ref_air_2[y, x, :], label='Radiancia reflejada del aire')
plt.plot(wave_lengths/1000, resultado_nuevo_2, label='Metodo nuevo')
#plt.plot(wave_lengths/1000, resultado_teorico, linestyle='--', label='Radiancia teorica')
plt.plot(wave_lengths/1000, black_body_air, label='B_air')
plt.plot(wave_lengths/1000, black_body, label='B_obj')
plt.plot(wave_lengths/1000, L_obj, label='L_obj')
plt.plot(wave_lengths/1000, L_air, label='L_air')

plt.grid()
# Leyenda debajo de la gráfica
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=4, frameon=True)
plt.subplots_adjust(bottom=0.1)
plt.show()

# %%
transmitancia = np.exp(-sigma_t * depth[y,x])

L_obj = transmitancia * firma * black_body  # Radiancia del objeto teorica
L_air = (1-transmitancia) * black_body_air  # Radiancia del aire teorica
L_ref = transmitancia * (1-firma) * black_body_air  # Radiancia reflejada teorica
resultado_antiguo = imagen_2[y,x,:] + (1-transmitancia) * black_body_air
resultado_nuevo_3 = imagen_2[y,x,:] + (1-transmitancia) * black_body_air + ref_air_3[y,x,:]
resultado_teorico = L_obj + L_air + L_ref

plt.figure(figsize=(15, 6))
plt.plot(wave_lengths/1000, resultado_antiguo, label='Metodo antiguo')
#plt.plot(wave_lengths/1000, ref_air_3[y, x, :], label='Radiancia reflejada del aire')
plt.plot(wave_lengths/1000, resultado_nuevo, label='Metodo nuevo')
plt.plot(wave_lengths/1000, resultado_teorico, linestyle='--', label='Radiancia teorica')
plt.plot(wave_lengths/1000, black_body_air, label='B_air')
plt.plot(wave_lengths/1000, black_body, label='B_obj')
# plt.plot(wave_lengths/1000, L_obj, label='L_obj')
# plt.plot(wave_lengths/1000, L_air, label='L_air')

plt.grid()
# Leyenda debajo de la gráfica
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=4, frameon=True)
plt.subplots_adjust(bottom=0.1)
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(wave_lengths/1000, ref_air_3[y, x, :], label='prueba 2')
plt.plot(wave_lengths/1000, ref_air[y, x, :], label='prueba 1')

plt.grid()
# Leyenda debajo de la gráfica
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=4, frameon=True)
plt.subplots_adjust(bottom=0.1)
plt.show()

# %%
# comparacion de firmas
transmitancia = np.exp(-sigma_t * depth[y,x])

plt.figure(figsize=(10, 5))
plt.plot(wave_lengths/1000, firma, label='emisividad')
plt.plot(wave_lengths/1000, 1-firma, label='reflectancia')
plt.plot(wave_lengths/1000, transmitancia, label='transmitancia')
plt.title("Transmitancia, Emisividad y Reflectancia")
plt.xlabel("Longitud de onda (μm)")
plt.ylabel("Valor")
plt.ylim(-0.1, 1.1)
plt.grid()

# %%
transmitancia = np.exp(-sigma_t * depth[y,x])
L_obj = transmitancia * firma * black_body  # Radiancia del objeto teorica
L_air = (1-transmitancia) * black_body_air  # Radiancia del aire
L_ref = transmitancia * (1-firma) * black_body_air  # Radiancia reflejada teorica
resultado_teorico = L_obj + L_air + L_ref

## prueba de resultados diferentes
plt.figure(figsize=(15, 6))
plt.plot(wave_lengths/1000, resultado_nuevo, label='Metodo nuevo 1', linestyle='--')
plt.plot(wave_lengths/1000, resultado_nuevo_2, label='Metodo nuevo 2', linestyle=':')
plt.plot(wave_lengths/1000, resultado_nuevo_3, label='Metodo nuevo 3', linestyle='-.')
plt.plot(wave_lengths/1000, resultado_teorico, linestyle='-', label='Radiancia teorica')
plt.plot(wave_lengths/1000, black_body_air, label='B_air')
plt.plot(wave_lengths/1000, black_body, label='B_obj')

plt.grid()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=4, frameon=True)
plt.subplots_adjust(bottom=0.1)
plt.show()
